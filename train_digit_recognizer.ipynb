# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape, y_train.shape)

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)
input_shape = (28, 28, 1)

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

batch_size = 128
num_classes = 10
epochs = 10

model = Sequential()
model.add(Conv2D(32, kernel_size=(5, 5),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])

hist = model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))
print("The model has successfully trained")

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

model.save('mnist.h5')
print("Saving the model as mnist.h5")
# Out:
# (60000, 28, 28) (60000,)
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 77s 1ms/step - loss: 0.3686 - accuracy: 0.8863 - val_loss: 0.0574 - val_accuracy: 0.9809
# Epoch 2/10
# 60000/60000 [==============================] - 76s 1ms/step - loss: 0.1055 - accuracy: 0.9724 - val_loss: 0.0382 - val_accuracy: 0.9882
# Epoch 3/10
# 60000/60000 [==============================] - 77s 1ms/step - loss: 0.0746 - accuracy: 0.9804 - val_loss: 0.0383 - val_accuracy: 0.9877
# Epoch 4/10
# 60000/60000 [==============================] - 76s 1ms/step - loss: 0.0625 - accuracy: 0.9845 - val_loss: 0.0307 - val_accuracy: 0.9905
# Epoch 5/10
# 60000/60000 [==============================] - 73s 1ms/step - loss: 0.0516 - accuracy: 0.9870 - val_loss: 0.0302 - val_accuracy: 0.9901
# Epoch 6/10
# 60000/60000 [==============================] - 73s 1ms/step - loss: 0.0450 - accuracy: 0.9886 - val_loss: 0.0315 - val_accuracy: 0.9913
# Epoch 7/10
# 60000/60000 [==============================] - 78s 1ms/step - loss: 0.0415 - accuracy: 0.9892 - val_loss: 0.0273 - val_accuracy: 0.9918
# Epoch 8/10
# 60000/60000 [==============================] - 82s 1ms/step - loss: 0.0360 - accuracy: 0.9911 - val_loss: 0.0277 - val_accuracy: 0.9919
# Epoch 9/10
# 60000/60000 [==============================] - 76s 1ms/step - loss: 0.0332 - accuracy: 0.9919 - val_loss: 0.0261 - val_accuracy: 0.9924
# Epoch 10/10
# 60000/60000 [==============================] - 74s 1ms/step - loss: 0.0304 - accuracy: 0.9923 - val_loss: 0.0284 - val_accuracy: 0.9916
# The model has successfully trained
# Test loss: 0.02841091223828166
# Test accuracy: 0.991599977016449
# Saving the model as mnist.h5
